# %% [markdown]
# <a href="https://colab.research.google.com/github/SebasRl07/Entregas/blob/main/Examen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Examen Funciones
#Sebastian Rugeles lopez
#Con Parametro y Retornando valor
#Punto 1.1
'Es un problema que recibe parametro y retorna valor'
p
#Hay que generar una lista en donde se separen todos los numeros que el usuario introduzca


def cantdigpares(Num):
  digits=str(Num)
  count=0

  for i in range(len(digits)):
    if (int(digits[i]) % 2 == 0):
      count += 1

  return count
Num=int(input('Ingrese un número:'))
print('La cantidad de digitos pares que tiene el numero que ingreso es:  ',cantdigpares(Num))
#Con Parámetro y sin Retornar Valor

def cantDigpares(Num):
  digits=str(Num)
  count=0

  for i in range(len(digits)):
    if (int(digits[i]) % 2 == 0):
      count += 1
  print('La cantidad de digitos pares que tiene el numero que ingreso es:  ',count)    

Num=int(input('Ingrese el número:'))
cantDigpares(Num)

#Sin Parámetro y sin retornar valor 
def cant_digpares():
  Num=int(input('Ingrese el número:'))
  digits=str(Num)
  count=0

  for i in range(len(digits)):
    if (int(digits[i]) % 2 == 0):
      count += 1
  print('La cantidad de digitos pares que tiene el número que ingreso es:', count)
cant_digpares()

#Sin parámetro y retornando valor
def cant_Digpares():
  Num=int(input('Ingrese el número:'))
  digits=str(Num)
  count=0

  for i in range(len(digits)):
    if (int(digits[i]) % 2 == 0):
      count += 1
  return count 
print('La cantidad de digitos pares que tiene el numero que ingreso es:  ',cant_Digpares())
# Out:
# Ingrese un número:10
# La cantidad de digitos pares que tiene el numero que ingreso es:   1
# Ingrese el número:20
# La cantidad de digitos pares que tiene el numero que ingreso es:   2
# Ingrese el número:30
# La cantidad de digitos pares que tiene el número que ingreso es: 1
# Ingrese el número:40
# La cantidad de digitos pares que tiene el numero que ingreso es:   2

# %%
#Punto 1.2
#Ejercicio funcion que valide números enteros y retorne el valor mayor
def num_Mayor(num1,num2):
  if num1==num2:
    print('Ambos números son iguales, Por favor ingrese otro número')
    return 0
  elif num1>num2:
    return num1
  else:
    return num2 

num1=int(input('Ingrese el número 1:'))
num2=int(input('Ingrese el número 2:')) 
print('El número mayor es:',num_Mayor(num1,num2))

#Ejercicio funcion que valide numeros enteros y no retorna valor

def num_mayor(num1,num2):
  if num1==num2:
    print('Ambos números son iguales, Por favor ingrese otro número')
    
  elif num1>num2:
    print('El numero mayor es:',num1)
  else:
    print('El numero mayor es:',num2) 

num1=int(input('Ingrese el número 1:'))
num2=int(input('Ingrese el número 2:')) 
num_mayor(num1,num2) 

#Ejercicio funcion que valide numeros enteros sin parametro y retornando valor
def numMayor():
  num1=int(input('Ingrese el número 1:'))
  num2=int(input('Ingrese el número 2:')) 
  if num1==num2:
    print('Ambos números son iguales, Por favor ingrese otro número')
    return 0
  elif num1>num2:
    return num1
  else:
    return num2 
 
print('El número mayor es:',numMayor())

#Ejercicio funcion que valide enteros sin parametros y sin retornar valor
def nummayor():
  num1=int(input('Ingrese el número 1:'))
  num2=int(input('Ingrese el número 2:')) 
  if num1==num2:
    print('Ambos números son iguales, Por favor ingrese otro número')
    
  elif num1>num2:
    print('El numero mayor es:',num1)
  else:
    print('El numero mayor es:',num2)  
 
print('El número mayor es:',nummayor())
# Out:
# Ingrese el número 1:2349
# Ingrese el número 2:4678
# El número mayor es: 4678
# Ingrese el número 1:345678
# Ingrese el número 2:98765
# El numero mayor es: 345678
# Ingrese el número 1:657893
# Ingrese el número 2:6657894
# El número mayor es: 6657894
# Ingrese el número 1:91356954145962
# Ingrese el número 2:015764017640645106741
# El numero mayor es: 15764017640645106741
# El número mayor es: None

# %%
#Punto 3.1
print('Bienvenido a mi programa, a continuación te mostraré el menú de opciones')
def menu():
  print('1. Para comparar 2 números y saber cuál es el mayor\n 2. Para saber la cantidad de digitos pares que tiene un número')
  respuesta=int(input('Ingrese el número que necesite:'))
  if respuesta==1:
    nummayor()
  elif respuesta ==2:
    cant_digpares()
  else:
    print('El número ingresado no es correcto, inténtelo de nuevo',menu())

menu()
# Out:
# Bienvenido a mi programa, a continuación te mostraré el menú de opciones
# 1. Para comparar 2 números y saber cuál es el mayor
#  2. Para saber la cantidad de digitos pares que tiene un número
# Ingrese el número que necesite:1
# Ingrese el número 1:10
# Ingrese el número 2:20
# El numero mayor es: 20

# %%
  #Punto 2
import pandas as pd 
import matplotlib.pyplot as plt
import os

arc_ex = pd.read_excel('data_ventas_video_juegos_1 1.xlsx')


def v_tot ():
  v_tot=arc_ex['Venta Millones'].sum() #Toma todos los valores de la columna.
  return v_tot #Los suma y retorna el valor en la variable.

def av_tot ():
    df = arc_ex
    df2 = df.groupby('Año').sum('Venta Millones')
    print(df2)

def v_plat ():

  df =arc_ex[['Plataforma', 'Venta Millones']]
  df2 = df.groupby('Plataforma').sum('Venta Millones')
  print(df2)

def ap_max (i):
    
    df = arc_ex[arc_ex['Año']==i][['Plataforma','Venta Millones']]
    df2 = df.groupby('Plataforma').sum('Venta Millones')
    max_df2 = df2['Venta Millones'].max()
    print(df2[df2['Venta Millones']==max_df2])

def jc_max (j):
  df = arc_ex[arc_ex['Nombre']==j][['Región','Venta Millones']]
  df2 = df.groupby('Región').sum('Venta Millones')
  print(df2)
  print(a)


def rj_max (r):
  df = arc_ex[arc_ex['Región']==r][['Nombre','Venta Millones']]
  df2 = df.groupby('Nombre').sum('Venta Millones')
  max_df2 = df2['Venta Millones'].max()
  print(df2[df2['Venta Millones']==max_df2])


def cv_tot ():
  df= arc_ex[['Región','Venta Millones']]
  df2 = df.groupby('Región').sum('Venta Millones')
  # print(df2)
  region=list(df['Región'].unique())
  region.sort()
  venta = list(df2['Venta Millones'])
  explode = (0.05, 0.05, 0.05, 0.05)

  print(df2)
  plt.pie(venta , labels=region, explode=explode)
  centre_circle = plt.Circle((0, 0), 0.70, fc='white')
  fig = plt.gcf()
  fig.gca().add_artist(centre_circle)

  plt.show


def av_tot_chart ():
    df = arc_ex
    df2 = df.groupby('Año').sum('Venta Millones')
    l_a = list(df['Año'].unique())
    l_a = sorted(l_a)
    l_v = list(df2['Venta Millones'])

    print(df2)
    plt.bar(l_a,l_v)
    plt.xlabel('Años ')
    plt.ylabel('Venta Millones')
    plt.title('Venta en Años')


def vp_tot ():
    df = arc_ex[['Plataforma','Venta Millones']]
    df3 = df.groupby('Plataforma').sum('Venta Millones')
    l_a = list(df['Plataforma'].unique())
    l_v = list(df3['Venta Millones'])
    pl=['2600A', 'PS', 'N64', 'PS2', 'DS', '3DS', 'Wii', 'PS3', 'X360', 'PS4', 'WiiU', 'XOne', 'PSP', 'PSV', 'XB', 'PC', 'GBA', 'GC', 'SNES', 'NES', 'SAT', 'GEN', 'DC', 'GB', '3DO', 'TG16', 'NG', 'SCD']
    pl.sort()
    print(df3)
    plt.barh(pl,l_v)
    plt.xlabel('Venta Millones')
    plt.ylabel('Plataforma')
    plt.title('Venta en Años')

def g_tot ():
  df = arc_ex[['Genero', 'Venta Millones']]
  df1 = df.groupby('Genero').sum('Venta Millones')
  print(df1)
  l_g = list(df['Genero'].unique())
  l_g.sort()
  l_vm = list(df1['Venta Millones'])
  explode = (0.05, 0.05, 0.05, 0.05, 0.05)
  
  plt.pie(l_vm , labels=l_g, explode=explode)
  centre_circle = plt.Circle((0, 0), 0.70, fc='white')
  fig = plt.gcf()
  fig.gca().add_artist(centre_circle)

  plt.show

def r_tot ():
  df = arc_ex[['Región','Venta Millones']]
  df1 = df.groupby('Región').sum('Venta Millones')
  l_r = list(df['Región'].unique())
  l_r.sort()
  l_vm = list(df1['Venta Millones'])
  explode = (0.05, 0.05, 0.05, 0.05)
  
  plt.pie(l_vm , labels=l_r, explode=explode)
  print(df1)


def menu():
  """
  Función que limpia la pantalla y muestra nuevamente el menu
  """
  os.system('clear') #NOTA para windows tienes que cambiar clear para cls
  print ("Selecciona una opción")
  print ("\t1 - Calcular ventas totales")
  print ("\t2 - Calcular ventas totales por año")
  print ("\t3 - Calcular ventas totales por plataforma")
  print ("\t4 - Calcular ventas totales por plataforma")
  print ("\t5 - Calcular ventas de juego por Regiónd")
  print ("\t6 - Calcular el juego mas vendido en una región")
  print ("\t7 - Graficar ventas totales por región")
  print ("\t8 - Graficar ventas totales por año ")
  print ("\t9 - Graficar vantas totales por plataforma")
  print ("\t10 - Graficar ventas por genero de juego")
  print ("\t11- Graficar ventas por continente")

  print ("\t12 - salir")

while True:
  #Mostramos el menu
  menu()

  #Punto 3.2
  #Solicitamos una opción al usuario
  opcionMenu = input("Inserta un número valor >> ")

  if opcionMenu=="1":

    print("")
    input("Has pulsado la opción 1...\npulsa una tecla para continuar")
    print(v_tot())

  elif opcionMenu=="2":

    print("")
    input("Has pulsado la opción 2...\npulsa una tecla para continuar")
    print(av_tot())

  elif opcionMenu=="3":

    print("")
    input("Has pulsado la opción 3...\npulsa una tecla para continuar")
    print(v_plat())

  elif opcionMenu=="4":

    print("")
    input("Has pulsado la opción 4...\npulsa una tecla para continuar")
    i=int(input('Ingresar año: '))
    print(ap_max(i))

  elif opcionMenu=="5":

    print("")
    input("Has pulsado la opción 5...\npulsa una tecla para continuar")
    j=str(input('Ingresar nombre del juego: '))
    jc_max(j)

  elif opcionMenu=="6":

    print("")
    input("Has pulsado la opción 6...\npulsa una tecla para continuar")
    r=str(input('Ingresar región: '))
    rj_max(r)

  elif opcionMenu=="7":
    print("")
    input("Has pulsado la opción 7...\npulsa una tecla para continuar")
    print(cv_tot())

  elif opcionMenu=="8":

    print("")
    input("Has pulsado la opción 8...\npulsa una tecla para continuar")
    print(av_tot_chart())

  elif opcionMenu=="9":

    print("")
    input("Has pulsado la opción 9...\npulsa una tecla para continuar")
    print(vp_tot())

  elif opcionMenu=="10":

    print("")
    input("Has pulsado la opción 10...\npulsa una tecla para continuar")
    print(g_tot())

  elif opcionMenu=="11":

    print("")
    input("Has pulsado la opción 11...\npulsa una tecla para continuar")
    print(r_tot())
  elif opcionMenu=="12":
    break
  else:
    print("")
    input("No has pulsado ninguna opción correcta...\npulsa una tecla para continuar ")
# Out:
# Selecciona una opción
# 	1 - Calcular ventas totales
# 	2 - Calcular ventas totales por año
# 	3 - Calcular ventas totales por plataforma
# 	4 - Calcular ventas totales por plataforma
# 	5 - Calcular ventas de juego por Regiónd
# 	6 - Calcular el juego mas vendido en una región
# 	7 - Graficar ventas totales por región
# 	8 - Graficar ventas totales por año
# 	9 - Graficar vantas totales por plataforma
# 	10 - Graficar ventas por genero de juego
# 	11- Graficar ventas por continente
# 	12 - salir
# Inserta un número valor >> 2
#
# Has pulsado la opción 2...
# pulsa una tecla para continuara
#       Venta Millones
# Año
# 1980            3.81
# 1981           21.71
# 1982           11.86
# 1983            8.95
# 1984            3.99
# 1985            6.99
# 1986           20.48
# 1987           12.65
# 1988            4.73
# 1989            8.45
# 1990            8.75
# 1991           12.21
# 1992           43.60
# 1993           17.51
# 1994           33.31
# 1995           34.69
# 1996           62.14
# 1997           58.65
# 1998          102.71
# 1999           79.75
# 2000           80.93
# 2001          108.04
# 2002          147.11
# 2003          125.34
# 2004          150.17
# 2005          186.95
# 2006          173.62
# 2007          246.09
# 2008          291.45
# 2009          271.32
# 2010          261.10
# 2011          215.27
# 2012          160.60
# 2013          174.47
# 2014          148.34
# 2015           99.14
# 2016           27.53
# 2017            0.01
# None
# Selecciona una opción
# 	1 - Calcular ventas totales
# 	2 - Calcular ventas totales por año
# 	3 - Calcular ventas totales por plataforma
# 	4 - Calcular ventas totales por plataforma
# 	5 - Calcular ventas de juego por Regiónd
# 	6 - Calcular el juego mas vendido en una región
# 	7 - Graficar ventas totales por región
# 	8 - Graficar ventas totales por año
# 	9 - Graficar vantas totales por plataforma
# 	10 - Graficar ventas por genero de juego
# 	11- Graficar ventas por continente
# 	12 - salir
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-50183c1897de> in <module>
#     140
#     141   #Solicitamos una opción al usuario
# --> 142   opcionMenu = input("Inserta un número valor >> ")
#     143
#     144   if opcionMenu=="1":
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     861             self._parent_ident,
#     862             self._parent_header,
# --> 863             password=False,
#     864         )
#     865
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
